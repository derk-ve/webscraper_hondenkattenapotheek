# %%
from price_comparer.price_comparer import PriceComparer
from datetime import datetime

# %%
date = datetime.now().strftime("%d_%m_%Y")
date
# Out:
# '23_04_2025'

# %%
old_file_date = "14_04_2025"
new_file_date = "23_04_2025"

# %%
old_file_path = f"C:/Users/derkv/OneDrive/Documenten/Brightminds/Webscraper/result_data/result_{old_file_date}.xlsx"
new_file_path = f"C:/Users/derkv/OneDrive/Documenten/Brightminds/Webscraper/result_data/result_{new_file_date}.xlsx"

# %%
comparer = PriceComparer(old_file_path, new_file_path)
diff, new_rows, removed_rows = comparer.run()

# %%
diff.to_excel(f"C:/Users/derkv/OneDrive/Documenten/Brightminds/Webscraper/comparison_data/{new_file_date}_diff_to_{old_file_date}.xlsx", index = False)

# %%
diff
# Out:
#                           product_name   pet     brand             size  \
# 0  hond|milbemax|L (5 - 25kg)|2.0 tabl  hond  milbemax     L (5 - 25kg)
# 1  hond|milbemax|L (5 - 25kg)|4.0 tabl  hond  milbemax     L (5 - 25kg)
# 2   hond|milbemax|S (0 - 5kg)|4.0 tabl  hond  milbemax      S (0 - 5kg)
# 3     hond|seresto|S (< 8 kg)|2.0 pack  hond   seresto       S (< 8 kg)
# 4  hond|vectra|XS (1,5 - 4 kg)|3.0 pip  hond    vectra  XS (1,5 - 4 kg)
#
#    quantity_package quantity_package_unit  quantity_ordered  \
# 0               2.0                  tabl                 1
# 1               4.0                  tabl                 1
# 2               4.0                  tabl                 1
# 3               2.0                  pack                 1
# 4               3.0                   pip                 1
#
#    price_medpets_old  price_medpets_new is_owned_medpets_old  \
# 0              11.05              11.25                 <NA>
# ...
